# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\IKIT-SILA\Desktop\SGAT\Исследование Карел-Хакас\Карел 2614\1_музей4.csv", encoding="utf-8")
a = df["Название"].tolist()

a
# Out:
# ['Фотография. Лээна Хеленурм, Карел - М. Клоорен?, сидят на кровати. "В вихре ветров" (пост. Б. Друй.). Эстония, Таллин. Таллинский драматический театр им В.Кингисеппа',
#  'Фотография. Лээна Хеленурм, Карел - Мати Клорен, Лээна сидит на телеге, Каарел уходит, машет рукой. "В вихре ветров" (пост. Б. Друй.). Эстония, Таллин. Таллинский драматический театр им В.Кингисеппа',
#  'Фотография. Сцена из спектакля. Девять бойцов, в центре, на столе стоит боец с баяном. "Василий Теркин" (пост. Д. Утикеев, худ. А. Шелковников, дир. Л. Ковалев.). Петрозаводск (Республика Карелия), Музыкальный театр',
#  'Фотография. Либр. И. Петровский, И. Берленда. В. Матвеева - Золушка, А. Усиченко - Принц. Золушка - слева, в бальном платье, лицо - фас; Принц - справа, лицо - 3/4 вправо. Держит руки Золушки. Оба - в рост. "Золушка" (пост. Д. Утикеев, худ. В. Скорик, дир. Л. Балло). Петрозаводск (Республика Карелия), Музыкальный театр',
# ...

# %%
aa = []

g = 'Карелин'
for i in range(len(a)):
    if g in a[i]:
        aa.append(i)

len(aa)
# Out:
# 0

# %%
df = pd.read_csv(r"C:\Users\IKIT-SILA\Desktop\SGAT\1.csv", encoding="utf-8")
df = df.drop(labels = aa,axis = 0)
df.to_csv(r'1_new.csv', encoding="utf-8", index=False)

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\IKIT-SILA\Desktop\SGAT\1_new.csv", encoding="utf-8")
a = df["ID_Музея"].tolist()

print(a)


aa = []

g = 171
for i in range(len(a)):
    if a[i] != g:
        aa.append(i)

df = df.drop(labels = aa,axis = 0)
df.to_csv(r'1_музей-0.csv', encoding="utf-8", index=False)
# Out:
# [1595, 186, 2595, 95, 95, 95, 2614, 2614, 2595, 2595, 524, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 1392, 1704, 1364, 1364, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 191, 191, 191, 191, 191, 191, 191, 191, 191, 2614, 2614, 345, 2614, 2125, 95, 95, 2125, 95, 95, 2125, 95, 95, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 191, 2717, 1435, 2375, 2375, 1741, 173, 1659, 3781, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2076, 2076, 2076, 1190, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 2614, 261
# ...
